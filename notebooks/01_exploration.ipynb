# %% [markdown]
# Code for Data exploration

# %%
import os
print(os.getcwd())
# Out:
# /Users/negar/DegradationLab/notebooks

# %%
from scipy.io import loadmat
import pandas as pd

# %%
mat_data = loadmat("/Users/negar/DegradationLab/data/B0025.mat")

# %%
mat_data.keys()
battery = mat_data["B0025"]
battery["cycle"].shape
# Out:
# (1, 1)

# %%
cycles = battery["cycle"][0, 0][0]

# %%
cycles.shape #it has 1 row and 80 columns
# Out:
# (80,)

# %%
cycles.dtype #it is an object type
# Out:
# dtype([('type', 'O'), ('ambient_temperature', 'O'), ('time', 'O'), ('data', 'O')])
